# %% [markdown]
# Имеется AI по типу ChatGPT. Выпустили обновление, которое должно улучшить выдачу ответов и снизить кол-во нажатий на 'generate answer again'. Необходимо узнать, действительно ли оно лучше.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from tqdm import tqdm
# %matplotlib inline

sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
size = 10000000
user_id = np.random.choice(size, size, replace=False)
gen_again = np.random.gamma(2, scale=0.5, size=size)
data = pd.DataFrame({'user_id': user_id,
                     'gen_again': gen_again})
data.head()
# Out:
#    user_id  gen_again
# 0  5771612   3.046674
# 1  1588780   1.286857
# 2  6674061   0.274180
# 3  4341783   0.081699
# 4  4141382   1.058972

# %%
print(data.gen_again.describe())
plt.figure(figsize=(20,7))
sns.histplot(data=data.gen_again, bins=50)
# Out:
# count    1.000000e+07
# mean     9.994601e-01
# std      7.066965e-01
# min      3.175676e-05
# 25%      4.801379e-01
# 50%      8.388422e-01
# 75%      1.345708e+00
# max      1.062384e+01
# Name: gen_again, dtype: float64
# <Axes: xlabel='gen_again', ylabel='Count'>

# %%
means = []
for _ in tqdm(range(10000)):
    means.append(data.gen_again.sample(100000, replace=True).mean())
means = pd.Series(means)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [01:16<00:00, 130.81it/s]

# %%
# Out:
# <Axes: >
